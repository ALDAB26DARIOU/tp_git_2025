# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %%
villes = ["Deroua","Tata","Temara","Agadir", "Larache"]
specialites = ["Neurochirurgien","Dentiste","Dermatologue","Cardiologue", "Ophtalmologue"]

base = "https://www.dabadoc.com/ma"
da = []
for spe in specialites:
    for ville in villes:
        url = base+"/"+spe+"/"+ville
        req = requests.get(url)
        soup = BeautifulSoup(req.text, 'html.parser')
        table = soup.find(class_ = "search_doc_table")
        if table == None :
            print("aucun "+spe+" dans la ville : "+ville)
            continue
        docs = table.find_all(attrs = {"class":"result-box"})
        for doc in docs:
            medecin = doc.find(class_ = 'profile_url')
            link = medecin.get('href')
            name = medecin.get_text()
            spec = doc.find('p').get_text().strip()
            d = [name, spec, link]
            da.append(d)

data = pd.DataFrame(da, columns = ["name","specialisation","link"])
data.head()
# Out:
# aucun Neurochirurgien dans la ville : Deroua
# aucun Neurochirurgien dans la ville : Tata
# aucun Neurochirurgien dans la ville : Temara
# aucun Neurochirurgien dans la ville : Larache
# aucun Dentiste dans la ville : Deroua
# aucun Dentiste dans la ville : Tata
# aucun Dermatologue dans la ville : Deroua
# aucun Dermatologue dans la ville : Tata
# aucun Cardiologue dans la ville : Tata
# aucun Ophtalmologue dans la ville : Deroua
# aucun Ophtalmologue dans la ville : Tata
#                   name            specialisation  \
# 0     Dr Youssef Tamri  Neurochirurgien à Agadir
# 1      Dr Mbark Arjdal  Neurochirurgien à Agadir
# 2    Abdelhafid Errami  Neurochirurgien à Agadir
# 3  Abderrahman Lagdani  Neurochirurgien à Agadir
# 4          Hicham Riad  Neurochirurgien à Agadir
#
#                                                 link
# 0  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 1  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 2  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 3  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 4  https://www.dabadoc.com/ma/neurochirurgien/aga...

# %%
data[data["specialisation"]=="Neurochirurgien à Agadir"]
# Out:
#                    name            specialisation  \
# 0      Dr Youssef Tamri  Neurochirurgien à Agadir
# 1       Dr Mbark Arjdal  Neurochirurgien à Agadir
# 2     Abdelhafid Errami  Neurochirurgien à Agadir
# 3   Abderrahman Lagdani  Neurochirurgien à Agadir
# 4           Hicham Riad  Neurochirurgien à Agadir
# 5   Dr Mohamed El Malki  Neurochirurgien à Agadir
# 6   Abderrazak Zerouali  Neurochirurgien à Agadir
# 7  Dr Abdelhafid Errami  Neurochirurgien à Agadir
#
#                                                 link
# 0  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 1  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 2  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 3  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 4  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 5  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 6  https://www.dabadoc.com/ma/neurochirurgien/aga...
# 7  https://www.dabadoc.com/ma/neurochirurgien/aga...

# %%
df = data.copy()

# %%
data["telephone"]=None
data["presentation"]=None
for index,col in data.iterrows():
    lien = col["link"]
    req1 = requests.get(lien)
    soup1 = BeautifulSoup(req1.text, 'html.parser')
    balise1= soup1.find(id="phone-number-btn")
    if balise1 != None :
        number = balise1.get('href')[4::]
        data.loc[index,'telephone']=number
     
    balise2 = soup1.find_all(class_ = "card")
    for card in balise2:
        if card.find(class_ = "fa fa-building") != None :
            break
    if card != None :
        if card.find('p') != None :
            present = card.find('p').get_text()
            data.loc[index,'presentation'] = present
   
data.head()
# Out:
#                   name            specialisation  \
# 0     Dr Youssef Tamri  Neurochirurgien à Agadir
# 1      Dr Mbark Arjdal  Neurochirurgien à Agadir
# 2    Abdelhafid Errami  Neurochirurgien à Agadir
# 3  Abderrahman Lagdani  Neurochirurgien à Agadir
# 4          Hicham Riad  Neurochirurgien à Agadir
#
#                                                 link telephone  \
# 0  https://www.dabadoc.com/ma/neurochirurgien/aga...      None
# 1  https://www.dabadoc.com/ma/neurochirurgien/aga...      None
# 2  https://www.dabadoc.com/ma/neurochirurgien/aga...      None
# 3  https://www.dabadoc.com/ma/neurochirurgien/aga...      None
# 4  https://www.dabadoc.com/ma/neurochirurgien/aga...      None
#
#                         presentation
# 0                               None
# 1  Cabinet médicale : consultation\n
# 2                               None
# 3                               None
# 4                               None

# %%
#faire un strip() sur la colonne presention du data frame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.tail(10)
#
# NameError: name 'data' is not defined
